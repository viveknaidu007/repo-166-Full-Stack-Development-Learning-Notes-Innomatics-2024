# %% [markdown]
# # Grid , Grid Layout and Responsive ( Media Query )

# %%
# Agenda :
* what is GRID :
* Make Grid Responsive
* What is Responsive

# %%
// shortcuts for creating tags :

div.box*9


div.box{this is box-$}*9

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title> GRID </title>

    <style>
        .box{
            border: 2px solid red;
        }
    </style>
</head>
<body>
    
    <div class="container">
        <div class="box">this is box-1</div>
        <div class="box">this is box-2</div>
        <div class="box">this is box-3</div>
        <div class="box">this is box-4</div>
        <div class="box">this is box-5</div>
        <div class="box">this is box-6</div>
        <div class="box">this is box-7</div>
        <div class="box">this is box-8</div>
        <div class="box">this is box-9</div>
    </div>
    
</body>
</html>

# %%
        .container{
            display:grid;
            grid-template-columns: 100px 100px;
        }


        .container{
            display:grid;
            grid-template-columns: repeat(4,200px);
                }


        .box{
            border: 2px solid red;
            padding : 30px;
        }

# %%
//////

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title> GRID </title>

    <style>

        #box-1{
            grid-area: navbar;
        }

        #box-2{
            grid-area: leftSide;
        }

        #box3{
            grid-area: FeedSection
        }

        #box4{
            grid-area: ChatBox;
        }

        #box5{
            grid-area: Footer;
        }

        .container{
            display: grid;
            grid-template-areas:
            "navbar navbar navbar navbar"
            "leftSide FeedSection FeedSection ChatBox"
            "FooterSection FooterSection FooterSection FooterSection";
        }

        .box{
            border: 2px solid gray;
            padding : 50px
        }

    </style>

</head>
<body>

    <div class="container">
        <div class="box" id="box-1">
            home about services contactus login and signup
        </div>

        <div class="box" id="box-2">
            this is my left side (portfolio)
        </div>

        <div class="box" id="box-3"> this my feeds section</div>
        <div class="box" id="box-4"> this is my chat box</div>
        <div class="box" id="box-5"> Footer Section</div>

    </div>
    
</body>
</html>

# %%
/////////////////

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
    <style>
        .box{
            background-color: black;
            color: white;
        }

        @media (max-width:500px){
            .box{
                background-color: red;
                color: yellow;
            }
        }
    </style>

</head>


<body>
    <div class="box">
        sadjlfcldsfnlksfk
        dfnisklgnkSFNDGN
        'SDGVNIKDF
        FIOLNG
        
        fnign
        
        '
    </div>
</body>


</html>
